# %% [markdown]
# # Agents
#
# Author: Boost Education Inc.
#
# Licence: Private
#
# Edit: 3/01/2024

# %% [markdown]
# ## Imports

# %%
pip install git+https://github.com/Boost-Education-Inc/agents_package.git@angentArchitecture boto3
# Out:
# ...
#   Cloning https://github.com/Boost-Education-Inc/agents_package.git (to revision angentArchitecture) to /private/var/folders/2f/4qv4v6_s6714t7lb2hc6jtqh0000gn/T/pip-req-build-_4ulvut7
#   Running command git clone --filter=blob:none --quiet https://github.com/Boost-Education-Inc/agents_package.git /private/var/folders/2f/4qv4v6_s6714t7lb2hc6jtqh0000gn/T/pip-req-build-_4ulvut7
#   Running command git checkout -b angentArchitecture --track origin/angentArchitecture
#   Switched to a new branch 'angentArchitecture'
#   branch 'angentArchitecture' set up to track 'origin/angentArchitecture'.
#   Resolved https://github.com/Boost-Education-Inc/agents_package.git to commit 2c97c18a371e4888490f0f11c3336b9ddb5fd5d1
#   Preparing metadata (setup.py) ... done
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from boostEdu.agents import *
import boto3
from IPython.display import Audio, display

# %%
os.environ["OPEN_AI_KEY"] = "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"
os.environ["OPEN_AI_MODEL_NAME"] = "gpt-4-1106-preview"
os.environ["DB_USERNAME"] = "juansebastian"
os.environ["DB_PASSWORD"] = "VBxwUiGBv9fHN1AW"
os.environ["DB_NAME"] = "boost_test"
os.environ["AWS_ACCESS_KEY_ID"] = "AKIARXK6G7ZU4QEX32WV"
os.environ["AWS_SECRET_ACCESS_KEY"] = "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"
learner_id='574ff357-0d48-41af-a199-9c43faad523e'
content_id='686b3259-7e9d-4493-85f0-380d3cf8eb6b'

# %%
polly_client = boto3.Session(region_name='us-east-1').client('polly')
s3 = boto3.client('s3')
awsManager=AWSManager(polly_client=polly_client, s3=s3)
# Out:
# INFO:botocore.credentials:Found credentials in environment variables.

# %% [markdown]
# ## Playground

# %% [markdown]
# ### Simple Agent

# %%
agent = Agent(agid='1')

# %% [markdown]
# ### Student Agent

# %%
learner = Learner(learner_id=learner_id)
learner.initLongMemory(content_id=content_id)

# %%
learner.workingMemory
# Out:
# "{'name': 'Jorge Smith', 'age': 23, 'gender': 'masculino', 'description': 'I like coding, spending my time in the zoo watching kangaroos and my goal is to start implementing tech in the education industry.'}"

# %%
learner.longMemory
# Out:
# ['2024-01-05 11:51:29:Based on the class interactions with my tutor, here\'s a detailed summary of what I have learned, what I have to learn, and what I have to practice:\n\n**What I Have Learned:**\n- The book we discussed is "The Art of War" by Sun Tzu, a classic text on military strategy and philosophy.\n- The book is divided into 13 chapters, each addressing a different aspect of warfare.\n- Understanding and utilizing various types of terrain is crucial in strategy. Sun Tzu identifies several types of ground, such as Contentious Ground, Open Ground, and Ground of Intersecting Highways.\n- The principles of military attack involve using both direct and indirect methods. Direct attacks are straightforward, while indirect attacks involve deception and surprise.\n- The combination of direct and indirect methods can lead to an infinite variety of strategies, much like combining basic tastes can create endless flavors.\n- Success in warfare, and by extension in any competitive situati
# ...

# %%
learner.speak(perception="What is your name?")
# Out:
# 'My name is Jorge Smith.'

# %% [markdown]
# ### Content Expert Agent

# %% [markdown]
# Here we can create a new contentAgent with the search and loading params or we can call an existing agent base on it´s id.

# %%
# contentAgent = ContentExpert(ret_params={
#   "agid":content_id,  
#   "type":"vectara",
#   "search_type":"similarity",
#   "keys":{
#     "vectara_customer_id":'3566257016',
#     "vectara_corpus_id":'3',
#     "vectara_api_key":"zwt_1JDDeIhw6YcfPnaW7VZotYx_lkbRqCMtTLzdcQ"
#   },
#   "search_kwargs":{
#     "k":40
#   }
# }
# )

# %%
contentExpert = ContentExpert(agid=content_id)
# Out:
# INFO:root:🔔Agent id: 686b3259-7e9d-4493-85f0-380d3cf8eb6b

# %%
content=contentExpert.speak(perception="Show me a summary of the book")

# %%
content
# Out:
# 'Content Metadata:\nTitle: The Art of War\nAuthor: Sun Tzu\nGenre: Military Strategy, Philosophy\nOriginal Language: Chinese\nDate of Publication: 5th century BC\n\nSummary:\n"The Art of War" by Sun Tzu is a seminal work on military strategy and tactics, written in ancient China. The text is a comprehensive guide for military commanders and has been influential in both Eastern and Western warfare and strategy.\n\nThe passages provided discuss various types of ground or terrain and their strategic importance in warfare. Sun Tzu categorizes the ground into different types, each with its own implications for military operations:\n\n1. Contentious Ground: This type of terrain offers significant advantages to whichever side controls it, making it a focal point for conflict.\n\n2. Open Ground: Terrain that allows freedom of movement for all forces involved and does not inherently offer a tactical advantage to either side.\n\n3. Ground of Intersecting Highways: This is a strategically cruci
# ...

# %% [markdown]
# ### Tutor Agent

# %%
tutor= Tutor(learner_id=learner_id,content_id=content_id)

# %% [markdown]
# #### Retrieve for chat (Not streaming and streaming)
#
# For streaming you must add the argument is_streaming=True in the constructor of the tutor.👆🏻

# %%
tutor_retrieve=tutor.speak(perception={
    "type":"chat",
    "studentData":learner.workingMemory,
    "studentLongMemory":learner.longMemory,
    "content": content,
    "question":"Show me a summary of the book",
    "awsManager":None
})

# %%
tutor_retrieve
# Out:
# 'Hey Jorge,\n\nSure thing! Here\'s a friendly summary of "The Art of War" for you:\n\n**Title:** The Art of War  \n**Author:** Sun Tzu  \n**Genre:** Military Strategy, Philosophy  \n**Original Language:** Chinese  \n**Date of Publication:** 5th century BC  \n\n**Summary:**  \n"The Art of War" is a classic text that delves into the intricacies of military strategy and tactics. Authored by the legendary Sun Tzu in ancient China, this guide has been a cornerstone for military leaders and strategists both in the East and the West.\n\nThe book is structured around key principles of warfare, emphasizing the importance of adaptability, understanding the terrain, and using both direct and indirect methods of engagement. Sun Tzu presents various types of terrain, such as Contentious Ground, Open Ground, and Ground of Intersecting Highways, each with its own strategic value.\n\nHe also introduces the concept of the five cardinal tastes—sour, acrid, salt, sweet, and bitter—to illustrate the lim
# ...

# %% [markdown]
# #### Presentation retrieve
#
# Here it returns the presentation

# %%
tutor_presentation_retrieve=tutor.speak(perception={
    "type":"presentation",
    "studentData":learner.workingMemory,
    "studentLongMemory":learner.longMemory,
    "content": content,
    "awsManager":None
})

# %%
tutor_presentation_retrieve
# Out:
# '```<div class="swiper" style="width: 40vw; height: 50vh; border-radius: 10px;">  <div class="swiper-wrapper">    <div class="swiper-slide" style="background-color: #1E90FF; color: white; font-family: Arial; text-align: center;">      <h2>The Art of War</h2>      <h4>Introduction to Strategy</h4>      <p>Discover the timeless military treatise on tactical warfare and strategy, a guide transcending eras, applicable to technology and education.</p>    </div>    <div class="swiper-slide" style="background-image: url(\'terrain.jpg\'); color: black; font-family: Arial; text-align: left;">      <h2>Contentious Ground</h2>      <h4>Strategic Advantage</h4>      <p>Like a pivotal tech innovation in education, this terrain offers significant benefits to those who control it, fostering competition.</p>    </div>    <div class="swiper-slide" style="background-color: #32CD32; color: white; font-family: Arial; text-align: right;">      <h2>Open Ground</h2>      <h4>Neutral Territory</h4>      <p>
# ...

# %% [markdown]
# #### Learning Plan path retrieve
#
# Here it retuns the learning plan path

# %%
tutor_learning_plan_retrieve=tutor.speak(perception={
    "type":"learning_plan",
    "studentData":learner.workingMemory,
    "studentLongMemory":learner.longMemory,
    "content": content,
    "awsManager":None
})

# %%
tutor_learning_plan_retrieve
# Out:
# '```\n<pre class="mermaid">\ngraph TD\n    A(("Identify Learning Objectives")) --> B(("Understand \'The Art of War\'"))\n    B --> C(("Apply Principles to Tech in Education"))\n    C --> D(("Develop Strategic Planning Skills"))\n    D --> E(("Practice Adaptability in Tech & Education"))\n    E --> F(("Create & Implement Tech Strategies"))\n</pre>\n```'

# %% [markdown]
# #### Presentation speech
#
# Here you can pass the presentation script and use AI to return an audio with the description of the presentation

# %%
speech=tutor.speak(perception={
    "type":"presentation_to_speech",
    "presentation_html_str":tutor_presentation_retrieve,
    "awsManager":awsManager,
    "sendToClientAPIGateway":False
})

# %%
speech
# Out:
# {'audio_url': 'https://boostfs.s3.amazonaws.com/temp/24c71828-13d7-4942-9973-8d015607912d.mp3',
# ...

# %%
display(Audio(speech['audio_url'], autoplay=True))
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Student Learning process

# %%
learner.learn(content_id=content_id)
